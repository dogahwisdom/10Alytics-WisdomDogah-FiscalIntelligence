# %% [markdown]
# # Fiscal Intelligence Analytics - Quick Start
#
# This notebook provides a quick introduction to using the Fiscal Intelligence Analytics Platform.

# %%
import sys
import os
sys.path.append(os.path.join(os.path.dirname(os.getcwd()), 'src'))

from data_processing import DataProcessor
from eda import EDAAnalyzer
from insights import InsightMiner
from models import ForecastingModel, RegressionModel
from visualization import VisualizationGenerator

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# %% [markdown]
# ## 2. Load and Process Data

# %%
# Initialize processor
processor = DataProcessor('../10Alytics Hackathon- Fiscal Data.xlsx')

# Process data
processed_data, processing_report = processor.process()

print(f"Data loaded: {processed_data.shape}")
print(f"Columns: {list(processed_data.columns)}")

# %% [markdown]
# ## 3. Exploratory Data Analysis

# %%
# Initialize EDA analyzer
eda_analyzer = EDAAnalyzer(processed_data)

# Get basic statistics
basic_stats = eda_analyzer.get_basic_statistics()
print("Basic Statistics:")
print(f"Shape: {basic_stats['shape']}")
print(f"Numeric columns: {len(eda_analyzer.numeric_cols)}")
print(f"Categorical columns: {len(eda_analyzer.categorical_cols)}")

# Analyze correlations
corr_matrix = eda_analyzer.analyze_correlations()
print("\nCorrelation Analysis Complete")

# %% [markdown]
# ## 4. Summary
#
# This quick start demonstrates the main capabilities:
# - ✅ Automated data processing
# - ✅ Comprehensive EDA
# - ✅ Advanced insight mining
# - ✅ Predictive modeling
# - ✅ Professional visualizations
#
# For more details, see the full documentation in the README.md file.
